# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
bos1 = pd.read_csv("BostonHousing.csv")
bos1
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
bos1.columns
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'b', 'lstat', 'medv'],
#       dtype='object')

# %%
x = bos1[['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax','ptratio', 'b', 'lstat']]
y = bos1["medv"]

# %%
sns.heatmap(bos1.corr())
plt.show()

# %%
bos1.corr()
# Out:
#              crim        zn     indus      chas       nox        rm       age  \
# crim     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# zn      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# indus    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# chas    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# nox      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# rm      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# age      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# dis     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# rad      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# tax      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# ptratio  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.20)

# %%
from sklearn.linear_model import LinearRegression #step 1 : Import
lm = LinearRegression() #step 2: Instantiate: Create an object 
lm.fit(X_train,y_train) #step 3 : Fit/Learn
pred_y = lm.predict(X_test) #step 4: Predict

# %%
plt.scatter(y_test,pred_y)

# %%
from sklearn.metrics import mean_squared_error

# %%
mse = mean_squared_error(y_test,pred_y)
mse
# Out:
# 23.257736416882135

# %% [markdown]
# # Second Model

# %%
x = bos1[['crim', 'zn', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'b']]
y = bos1["medv"]
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.20)

from sklearn.linear_model import LinearRegression #step 1 : Import
lm = LinearRegression() #step 2: Instantiate: Create an object 
lm.fit(X_train,y_train) #step 3 : Fit/Learn
pred_y = lm.predict(X_test) #step 4: Predict

mse = mean_squared_error(y_test,pred_y)
mse
# Out:
# 26.648443021079547

# %% [markdown]
# # Polynomial Regression

# %%
from sklearn.preprocessing import PolynomialFeatures #step 1: Import

# %%
poly = PolynomialFeatures(degree=2) #step 2
poly_features = poly.fit_transform(x)

# %%
poly_features
# Out:
# array([[1.00000000e+00, 6.32000000e-03, 1.80000000e+01, ...,
#         1.00000000e+00, 3.96900000e+02, 1.57529610e+05],
#        [1.00000000e+00, 2.73100000e-02, 0.00000000e+00, ...,
#         4.00000000e+00, 7.93800000e+02, 1.57529610e+05],
#        [1.00000000e+00, 2.72900000e-02, 0.00000000e+00, ...,
#         4.00000000e+00, 7.85660000e+02, 1.54315409e+05],
#        ...,
#        [1.00000000e+00, 6.07600000e-02, 0.00000000e+00, ...,
#         1.00000000e+00, 3.96900000e+02, 1.57529610e+05],
#        [1.00000000e+00, 1.09590000e-01, 0.00000000e+00, ...,
#         1.00000000e+00, 3.93450000e+02, 1.54802902e+05],
#        [1.00000000e+00, 4.74100000e-02, 0.00000000e+00, ...,
#         1.00000000e+00, 3.96900000e+02, 1.57529610e+05]])

# %%
X_train,X_test,y_train,y_test = train_test_split(poly_features,y,test_size=0.20)

# %%
poly_reg = LinearRegression()

# %%
poly_reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
poly_reg.coef_
# Out:
# array([ 2.08067140e+09,  3.48362734e+00, -3.57206040e-01,  3.25641755e+01,
#        -7.99398632e+01, -4.60469425e+00,  3.10262478e-01, -2.92793006e+00,
#         3.87964336e+00,  1.08073354e-01,  5.89658709e-03, -6.72413219e-02,
#         2.71113900e+00, -1.87509460e+00,  2.69342460e-02, -2.94263601e-03,
#        -5.50098768e-02, -1.04601994e-01, -5.21327615e-04,  7.45921835e-05,
#         1.00573723e-01,  4.52088190e-01,  2.55099743e-02, -3.10763420e-04,
#        -4.61478324e-03, -3.33868553e-03,  1.70079387e-04,  3.25641755e+01,
#        -6.65655398e+01, -2.19801016e+00,  3.60070067e-03, -5.25545723e+00,
#        -2.05444408e-03,  5.19844755e-03,  9.85395238e+01, -1.80930439e+00,
#        -5.42965915e-01,  4.22387286e+00, -5.61794792e-01, -3.39305359e-03,
#         1.36148463e+00,  1.20371835e-03, -2.39586261e-01, -4.18369759e-01,
#         4.40100746e-04,  4.70373152e-04,  6.49911297e-03,  1.59576887e-03,
# ...

# %%
y_pred = poly_reg.predict(X_test)
y_pred
# Out:
# array([23.21799898, 12.7654295 , 20.48207879,  5.34668636, 19.66243672,
#        29.28096628, 15.21900487, 19.44575357, 25.64600587, 19.56153274,
#        15.28137279, 21.26116371, 35.84342122, 49.01659656, 19.80553079,
#        23.29662514, 24.1553483 , 16.91129923, 23.98285818, 24.16259718,
#        13.75471687, 21.08532095, 38.15919757, 12.13607025, 17.71759057,
#        24.37044978, 20.52689004, 39.66302514, 15.36242962, 26.15660954,
#        15.51786542, 26.73821759, 16.7229774 , 27.84298015, 18.62361693,
#        15.81893587, 35.92759538, 16.77044868, 18.5714314 , 17.83190918,
#        18.63604903, 43.78791761, 27.86204505, 20.69507456, 16.22961831,
#        27.71925879, 17.947016  , 23.00221109, 49.83418608, 21.58727264,
#        21.71075535, 22.07616401, 12.21247554, 22.41875339, 11.06380057,
#        22.44613791, 15.45486426, 21.60715818, 17.76922035, 26.13018155,
#        33.74647617, 21.25376463, 28.6357789 , 18.79644203, 27.34635615,
# ...

# %%
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 4.462218339422807

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.7674164738928364

# %% [markdown]
# # Decision Trees

# %%
x = bos1[['crim', 'zn', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'b']]
y = bos1["medv"]
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.20)

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
regdt = DecisionTreeRegressor()

# %%
regdt.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred = regdt.predict(X_test)

# %%
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 4.903430171928666

# %%
r2_score(y_test,y_pred)
# Out:
# 0.7310376812327213

# %% [markdown]
# # Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
regrf = RandomForestRegressor(n_estimators=500)

# %%
regrf.fit(X_train,y_train)
# Out:
# RandomForestRegressor(n_estimators=500)

# %%
y_predrf = regrf.predict(X_test)
y_predrf
# Out:
# array([15.207 , 22.3744, 33.1776,  6.5314, 27.2342, 21.0176, 23.1622,
#        22.0048, 48.9562, 18.6522, 21.0892, 20.0648, 16.9308, 20.0076,
#        22.9476, 35.9578, 22.402 , 33.5194, 24.1126, 22.3128, 31.8132,
#        24.2934, 20.1138, 30.2046, 19.7428,  7.956 , 21.7196, 19.1542,
#        18.8212, 26.9828, 12.8716, 25.744 , 44.6678, 22.6668, 20.0388,
#        15.645 , 25.7552, 21.6916, 33.3812, 20.7904, 17.1342, 19.663 ,
#        16.0004, 41.951 , 14.0676, 26.818 , 20.2768, 44.5426, 20.9332,
#        18.286 , 16.5388, 15.5008, 10.6416, 20.066 , 23.9542, 22.208 ,
#        17.2652, 24.5032, 14.486 , 12.5094, 19.3286, 14.5978, 16.9324,
#        23.4398, 19.7634, 20.1822, 16.9914, 46.5956, 11.264 , 22.5378,
#        26.7062, 20.9072, 23.787 , 13.3636, 21.5618, 26.625 , 15.6178,
#        11.8788, 22.6958, 26.3478, 33.7514, 20.2376, 16.5952, 24.6778,
#        21.4972, 29.284 , 23.8062, 19.0068, 17.0286, 25.1526, 17.1002,
# ...

# %%
np.sqrt(mean_squared_error(y_test,y_predrf))
# Out:
# 4.273853312373547

# %%
r2_score(y_test,y_predrf)
# Out:
# 0.7956706871364967
