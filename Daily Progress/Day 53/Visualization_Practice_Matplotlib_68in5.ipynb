# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3,4,5,6,7,12,34,56])
plt.show()

# %%
x = list(range(5))
x
# Out:
# [0, 1, 2, 3, 4]

# %%
[x*y for x in range(3) for y in range(3,6)]
# Out:
# [0, 0, 0, 3, 4, 5, 6, 8, 10]

# %%
l1 = []
for x1 in x:
    l1.append(x1**2)

# %%
l1
# Out:
# [0, 1, 4, 9, 16]

# %%
y = [x1**2 for x1 in x]

# %%
x = range(5)
plt.plot(x,l1)
plt.show()

# %%
x = range(5)
x
# Out:
# range(0, 5)

# %%
plt.plot(x,[x1 for x1 in x])
plt.plot(x,[x1*x1 for x1 in x])
plt.plot(x,[x1*x1*x1 for x1 in x])
plt.grid(True)
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("This is my x graph")
plt.show()

# %%
x = np.arange(5)
x
# Out:
# array([0, 1, 2, 3, 4])

# %%
plt.plot(x,x*x*x,label="Cube")
plt.plot(x,x,label="Linear")
plt.plot(x,x*x,label="Squared")
plt.legend()
plt.grid(True)
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("This is my second graph")
plt.savefig("alka_graph.png")
plt.show()

# %%
y = np.random.randn(5,5)
y
# Out:
# array([[ 0.45340087,  0.88257487, -0.26032163, -2.16028847, -1.36905606],
#        [-1.3890083 , -0.54572319, -0.70720134, -0.04716962,  2.50528495],
#        [-0.63095393, -1.40323267, -0.4050411 , -0.38245247,  0.29851514],
#        [ 0.34560195,  0.5925398 , -0.91460174,  0.21646062, -0.75356571],
#        [-0.20401503,  0.55331361, -1.01100393,  0.81662371, -2.24878695]])

# %%
y = np.random.randn(100,100)
plt.hist(y)
# Out:
# (array([[ 0.,  3.,  4., 13., 26., 29., 17.,  8.,  0.,  0.],
#         [ 0.,  0.,  6., 20., 36., 17., 16.,  3.,  2.,  0.],
#         [ 0.,  4.,  7., 17., 18., 25., 16., 11.,  2.,  0.],
#         [ 0.,  1.,  8., 17., 20., 26., 19.,  5.,  4.,  0.],
#         [ 0.,  0.,  3., 17., 22., 32., 18.,  6.,  2.,  0.],
#         [ 0.,  0.,  1., 12., 28., 27., 21., 11.,  0.,  0.],
#         [ 0.,  0.,  6., 13., 22., 27., 20., 11.,  1.,  0.],
#         [ 1.,  1.,  6., 13., 30., 26., 18.,  4.,  1.,  0.],
#         [ 0.,  1.,  7., 16., 26., 21., 20.,  9.,  0.,  0.],
#         [ 0.,  1.,  5., 15., 32., 26., 14.,  5.,  2.,  0.],
#         [ 0.,  1.,  9., 11., 16., 30., 21., 10.,  2.,  0.],
#         [ 0.,  1.,  7., 20., 23., 24., 17.,  1.,  7.,  0.],
#         [ 0.,  1.,  8., 14., 19., 30., 17.,  8.,  2.,  1.],
#         [ 0.,  1.,  4., 10., 34., 17., 21., 13.,  0.,  0.],
#         [ 0.,  0.,  2., 21., 23., 24., 21.,  7.,  2.,  0.],
#         [ 1.,  1.,  2., 12., 27., 31., 20.,  4.,  2.,  0.],
# ...

# %%
y = np.random.randn(100)
plt.hist(y,20)
plt.show()

# %%
dict1 = {"City1":25,"City2":75,"City3":50,"City4":100}
dict1
# Out:
# {'City1': 25, 'City2': 75, 'City3': 50, 'City4': 100}

# %%
len(dict1)
# Out:
# 4

# %%
for i,key in enumerate(dict1):
    plt.bar(i,dict1[key])

plt.xticks(np.arange(len(dict1)),dict1.keys())
    
plt.show()

# %%
for i,key in enumerate(dict1):
    plt.bar(key,dict1[key])
#plt.xticks(np.arange(len(dict1)),dict1.keys())
    
plt.show()

# %%
plt.bar(dict1.keys(),dict1.values())
plt.show()

# %%
x = [40,30,10,20]
labels = ["Bike","Car","Cycle","Bus"]
plt.pie(x,labels=labels,autopct="%2.1f%%",colors =["red","blue","green","yellow"],explode=[0,0.4,0,0.4],shadow=True)
plt.show()

# %%
x = np.random.rand(100)
y = np.random.rand(100)
plt.scatter(x,y)
plt.show()

# %%
y = np.arange(1,3)
plt.plot(y,"y")
plt.plot(y+5,"m")
plt.plot(y+10,"c")
plt.show()

# %%
y = np.arange(1,3)
plt.plot(y,"--",y+5,"-.",y+10,":")
plt.show()

# %%
y = np.arange(1,5,0.2)
plt.plot(y,"*",y+5,"o",y+10,"D")
plt.show()
